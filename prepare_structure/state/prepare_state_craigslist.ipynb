# %%
import os
import sys
sys.path.append('../../src')

import copy
import collections
import datasets
import decouple
import json
import pandas as pd

import clustering
import clustering_utils
import utils

SCRATCH_DIR = decouple.config('SCRATCH_PARENT_DIR')
NFS_DIR = decouple.config('NFS_PARENT_DIR')

# %%
data_name = 'craigslist'
num_clusters = 14
embedding_name = 'bert_mean_pooler_output'
cuda_device = 0
debug_mode = False
overwrite = True

task_name = 'pretrain'
pos_type = 'absolute'

model_name = 'hibert'
data_config_path = f'../../config/data/{data_name}.yaml'

# %%
data_config = utils.read_yaml(data_config_path)

hmm_config_path = f'../../config/hmm/{data_name}.yaml' 
hmm_config = utils.read_yaml(hmm_config_path)

model_path = data_config['path']['dapt_model_path'].format(nfs_dir=NFS_DIR)
assert os.path.isdir(model_path), model_path

assignment_parent_dir = data_config['path']['assignment_dir'].format(nfs_dir=NFS_DIR)
assignment_dir = os.path.join(
    assignment_parent_dir, f'{embedding_name}/num_clusters_{num_clusters}')

state_assignment_parent_dir = \
    data_config['path']['state_assignment_dir'].format(nfs_dir=NFS_DIR)
os.makedirs(state_assignment_parent_dir, exist_ok=True)

print(f'{model_path = }')
print(f'{assignment_dir = }')
print(f'{state_assignment_parent_dir = }')

dataset_dir = data_config['path']['dataset_dir'].format(scratch_dir=SCRATCH_DIR)

local_ds_dir = utils.get_dataset_dir_map(
    task_name, dataset_dir, model_path, debug_mode)

raw_ds = datasets.DatasetDict.load_from_disk(local_ds_dir['raw_ds'])
ds = copy.deepcopy(raw_ds)
ds.set_format(type='torch', columns=['input_ids', 'attention_mask'])
# Out:
# model_path = '/gscratch/tial/roylu/projects/conversation_pretraining/pretrained_models/craigslist/bert-base-uncased-craigslist-wwm'
# assignment_dir = '/gscratch/tial/roylu/projects/conversation_pretraining/assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14'
# state_assignment_parent_dir = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm'

# %% [markdown]
# # Shows an example.

# %%
idx = 4
for turn in raw_ds['train']['dialogue'][idx]:
    utt = turn['turn']
    party = turn['party']
    print(f'{party:>10}: {utt}')
# Out:
#      buyer: <price>_-0.2
#     seller: that is a lot lower then i am willing to sell this item for .
#     seller: <offer>
#     seller: <quit>

# %%
split_to_cluster_seq_df = {}
split_to_centers = {}
for split in data_config['config']['splits']:
    assignment_path = os.path.join(assignment_dir, f'{split}.csv')
    center_path = os.path.join(assignment_dir, f'{split}_center.json')
    parties = [turn['party'] 
        for dialogue in raw_ds[split]['dialogue'] for turn in dialogue]
    df = pd.read_csv(assignment_path)
    df['party'] = parties
    cluster_seq_df = df.groupby('dialog_idx')['assignment'].apply(
        list).reset_index(name='cluster_sequence')
    cluster_seq_df['party_sequence'] = df.groupby('dialog_idx')['party'].apply(
        list)
    cluster_seq_df['turn_idx'] = df.groupby('dialog_idx')['turn_idx'].apply(
        list)

    split_to_cluster_seq_df[split] = cluster_seq_df

    with open(center_path, 'r') as f:
        split_to_centers[split] = json.load(f)

# %%
init_min_seq_len = hmm_config['init_min_seq_len']
topk_edges = hmm_config['topk_edges']
num_init_states = hmm_config['num_init_states']
max_iterations = hmm_config['max_iterations']
num_state_splits = hmm_config['num_state_splits']
topk_clusters = 3
topk_utterances_per_cluster = 3
topk_clusters_in_state = 3
n_jobs = 8
index_to_party = {v: k for k, v in data_config['config']['party_to_index'].items()}
speaker1 = index_to_party[0]
speaker2 = index_to_party[1]

# %%
cluster_to_utterances = {}
for cluster, neighbors in split_to_centers['train'].items():
    cluster_to_utterances[cluster] = \
        [f"{n['party']}: {n['turn']}" 
         for n in neighbors][:topk_utterances_per_cluster]
assert len(cluster_to_utterances) == num_clusters * 2

# %%
train_sequences = split_to_cluster_seq_df['train']['cluster_sequence'].tolist()
dev_sequences = split_to_cluster_seq_df['dev']['cluster_sequence'].tolist()
cluster_vocab = list(set(sum(train_sequences+dev_sequences, [])))

# %% [markdown]
# # Trains HMM and apply state-splitting algorithm to build topologies.

# %%
# Initializes 3-state left-to-right topology.
hmm = clustering.DiscreteSequenceClustering(
    init_min_seq_len,
    cluster_vocab,
    num_init_states=num_init_states,
    topk_edges=topk_edges)

hmm.build(train_sequences)

curr_split = 0
state_assignment_dir = os.path.join(
    state_assignment_parent_dir,
    f'{embedding_name}/num_clusters_{num_clusters}/'
    f'num_splits_{hmm.num_splits}_num_states_{hmm.num_states}_num_merging_{hmm.num_merging}')
utils.maybe_makedirs(state_assignment_dir, overwrite)

print(f'Total # splits = {num_state_splits}')
num_states_to_model = {}
for curr_split in range(1, num_state_splits+1):

    print('*'*50)
    print(f'Current split     = {curr_split}.')
    print(f'Current # states  = {hmm.num_states}.')
    print(f'Current # merging = {hmm.num_merging}.')
    print(f'Current # splits  = {hmm.num_splits}.')
    print('*'*50)

    print('='*50)
    print(f'Start splitting.')
    print('='*50)
    hmm.split_and_train(train_sequences, train_sequences, max_iterations, n_jobs)

    state_assignment_parent_dir, 
    state_assignment_dir = os.path.join(
        state_assignment_parent_dir, 
        f'{embedding_name}/num_clusters_{num_clusters}/'
        f'num_splits_{hmm.num_splits}_num_states_{hmm.num_states}_num_merging_{hmm.num_merging}')
    utils.maybe_makedirs(state_assignment_dir, overwrite)
    checkpoint_path = os.path.join(state_assignment_dir, f'hmm.joblib')

    hmm.save_model(checkpoint_path)
    num_states_to_model[hmm.num_states] = copy.deepcopy(hmm)
    print(f'Save hmm to {checkpoint_path = }')
    print('\n\n')

    title = state_assignment_dir

    # Plots figure and predicts state sequneces.
    hmm = clustering.ClusteringBase.from_pretrained(checkpoint_path)
    g = clustering.plot_hmm(hmm, topk_clusters, cluster_to_utterances, title=state_assignment_dir)
    image_path = os.path.join(state_assignment_dir, 'hmm')
    g.render(image_path, format='pdf')

    split_to_state_df = {}
    for split, seq_df in split_to_cluster_seq_df.items():
        sequences = seq_df['cluster_sequence'].tolist()
        seq_df['state_sequence'] = list(map(hmm.predict, sequences))
        df = seq_df[['dialog_idx', 'turn_idx', 'state_sequence']].explode(
            ['turn_idx', 'state_sequence']).reset_index(drop=True)
        df.rename(columns={'state_sequence': 'assignment'}, inplace=True)
        split_to_state_df[split] = df
        path = os.path.join(state_assignment_dir, f'{split}.csv')
        df.to_csv(path, index=False)
        print(f'Saves state assignment to {path}')
        
    clustering_utils.find_state_centers(
        data_config['config']['splits'],
        raw_ds,
        assignment_dir,
        state_assignment_dir,
        split_to_state_df,
        split_to_centers,
        topk_clusters_in_state=3)
# Out:
# Total # splits = 7
# **************************************************
# Current split     = 1.
# Current # states  = 3.
# Current # merging = 0.
# Current # splits  = 0.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: S01.
# Try temperal split.
# [1] Improvement: 19244.40710313071	Time (s): 0.614
# [2] Improvement: 3609.6564202539157	Time (s): 0.6352
# [3] Improvement: 3466.850087770523	Time (s): 0.4817
# [4] Improvement: 1436.824929560069	Time (s): 0.414
# [5] Improvement: 367.7437407761463	Time (s): 0.6321
# [6] Improvement: 142.46851961361244	Time (s): 0.6882
# [7] Improvement: 77.69782849171315	Time (s): 0.6563
# [8] Improvement: 49.953032260615146	Time (s): 0.685
# [9] Improvement: 36.54101103392895	Time (s): 0.6343
# [10] Improvement: 30.748550316668116	Time (s): 0.6455
# [11] Improvement: 29.908855021814816	Time (s): 0.6231
# [12] Improvement: 32.755997212429065	Time (s): 0.4922
# Total Training Improvement: 28525.556075442146
# Total Training Time (s): 7.8451
# Temperal log prob = -131165.3748
# Try vertical split.
# [1] Improvement: 21145.079940479685	Time (s): 0.6295
# [2] Improvement: 782.9860524092219	Time (s): 0.6317
# [3] Improvement: 535.5922045693733	Time (s): 0.6441
# [4] Improvement: 504.70653025840875	Time (s): 0.5806
# [5] Improvement: 369.9089790714206	Time (s): 0.6011
# [6] Improvement: 221.53443475204404	Time (s): 0.6231
# [7] Improvement: 132.0485989653098	Time (s): 0.6242
# [8] Improvement: 82.09441832694574	Time (s): 0.596
# [9] Improvement: 52.38431248618872	Time (s): 0.6271
# [10] Improvement: 34.398469559295336	Time (s): 0.6314
# [11] Improvement: 23.45402741516591	Time (s): 0.6031
# [12] Improvement: 16.669656456972007	Time (s): 0.6056
# Total Training Improvement: 23900.85762475003
# Total Training Time (s): 8.0996
# Vertical log prob = -139143.7004
# Use temperal split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_1_num_states_4_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_1_num_states_4_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_1_num_states_4_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_1_num_states_4_num_merging_0/test.csv
# **************************************************
# Current split     = 2.
# Current # states  = 4.
# Current # merging = 0.
# Current # splits  = 1.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: T00 <- S01.
# Try temperal split.
# [1] Improvement: 122.33536502422066	Time (s): 0.9677
# [2] Improvement: 113.76587202258816	Time (s): 0.9614
# [3] Improvement: 185.57646903664863	Time (s): 0.9651
# [4] Improvement: 273.8481458963797	Time (s): 0.8612
# [5] Improvement: 317.84921723153093	Time (s): 0.7932
# [6] Improvement: 341.95492599922	Time (s): 0.6267
# [7] Improvement: 366.9195886143425	Time (s): 0.6366
# [8] Improvement: 379.2223603501625	Time (s): 0.6222
# [9] Improvement: 359.37378176877974	Time (s): 0.6764
# [10] Improvement: 307.97188084230584	Time (s): 0.6996
# [11] Improvement: 245.56757292107795	Time (s): 0.7007
# [12] Improvement: 194.89451376945362	Time (s): 0.6645
# Total Training Improvement: 3209.2796934767102
# Total Training Time (s): 10.1459
# Temperal log prob = -127832.7229
# Try vertical split.
# [1] Improvement: 1776.8016024607787	Time (s): 0.6379
# [2] Improvement: 127.43478831210814	Time (s): 0.5993
# [3] Improvement: 88.25850376785093	Time (s): 0.6401
# [4] Improvement: 70.21849351706624	Time (s): 0.6514
# [5] Improvement: 54.8646564882074	Time (s): 0.6751
# [6] Improvement: 41.14049993795925	Time (s): 0.6308
# [7] Improvement: 29.726421406157897	Time (s): 0.6527
# [8] Improvement: 20.994463416922372	Time (s): 0.6028
# [9] Improvement: 14.829931812899304	Time (s): 0.6408
# Total Training Improvement: 2224.26936111995
# Total Training Time (s): 6.3565
# Vertical log prob = -130575.1534
# Use temperal split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_2_num_states_5_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_2_num_states_5_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_2_num_states_5_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_2_num_states_5_num_merging_0/test.csv
# **************************************************
# Current split     = 3.
# Current # states  = 5.
# Current # merging = 0.
# Current # splits  = 2.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: T00 <- S01.
# Try temperal split.
# [1] Improvement: 171.29171228529594	Time (s): 0.612
# [2] Improvement: 190.31834267963131	Time (s): 0.6012
# [3] Improvement: 201.99572264705785	Time (s): 0.7569
# [4] Improvement: 198.81493789941305	Time (s): 0.6685
# [5] Improvement: 175.96360185256344	Time (s): 0.6809
# [6] Improvement: 142.06380185601301	Time (s): 0.7057
# [7] Improvement: 111.51807662421197	Time (s): 0.723
# [8] Improvement: 88.67889506471693	Time (s): 0.7232
# [9] Improvement: 72.40063804996316	Time (s): 0.6776
# [10] Improvement: 60.89956738971523	Time (s): 0.6781
# [11] Improvement: 53.352139558279305	Time (s): 0.7293
# [12] Improvement: 49.42762431684241	Time (s): 0.7193
# Total Training Improvement: 1516.7250602237036
# Total Training Time (s): 8.7562
# Temperal log prob = -126267.8529
# Try vertical split.
# [1] Improvement: 775.0650224708806	Time (s): 0.661
# [2] Improvement: 187.89150838817295	Time (s): 0.6768
# [3] Improvement: 196.57500018761493	Time (s): 0.6634
# [4] Improvement: 200.39919406859553	Time (s): 0.681
# [5] Improvement: 186.12920538621256	Time (s): 0.6956
# [6] Improvement: 155.77253194533114	Time (s): 0.6859
# [7] Improvement: 121.9423068575561	Time (s): 0.7324
# [8] Improvement: 93.63670879480196	Time (s): 0.6834
# [9] Improvement: 72.3167732062575	Time (s): 0.7115
# [10] Improvement: 56.424939106742386	Time (s): 0.6772
# [11] Improvement: 44.56504487450002	Time (s): 1.02
# [12] Improvement: 35.47195872866723	Time (s): 1.09
# Total Training Improvement: 2126.190194015333
# Total Training Time (s): 9.6155
# Vertical log prob = -126369.1009
# Use temperal split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_3_num_states_6_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_3_num_states_6_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_3_num_states_6_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_3_num_states_6_num_merging_0/test.csv
# **************************************************
# Current split     = 4.
# Current # states  = 6.
# Current # merging = 0.
# Current # splits  = 3.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: T00 <- S01.
# Try temperal split.
# [1] Improvement: 54.09292769177409	Time (s): 1.181
# [2] Improvement: 69.94789662501717	Time (s): 1.184
# [3] Improvement: 98.17314235358208	Time (s): 1.123
# [4] Improvement: 149.3698020240845	Time (s): 0.7281
# [5] Improvement: 233.9826282429276	Time (s): 0.7611
# [6] Improvement: 344.55549582105596	Time (s): 0.7779
# [7] Improvement: 413.64550721533305	Time (s): 0.765
# [8] Improvement: 346.37006365640264	Time (s): 0.6977
# [9] Improvement: 191.01683050091378	Time (s): 0.724
# [10] Improvement: 81.89177742811444	Time (s): 0.7964
# [11] Improvement: 37.08185171592049	Time (s): 0.8162
# [12] Improvement: 21.073058584632236	Time (s): 0.7214
# Total Training Improvement: 2041.200981859758
# Total Training Time (s): 11.4491
# Temperal log prob = -124211.4481
# Try vertical split.
# [1] Improvement: 63.93351874475775	Time (s): 0.7255
# [2] Improvement: 56.80933337516035	Time (s): 0.7828
# [3] Improvement: 76.0853065220872	Time (s): 0.791
# [4] Improvement: 111.27380412509956	Time (s): 0.7121
# [5] Improvement: 173.19246718889917	Time (s): 0.7611
# [6] Improvement: 271.4062935510592	Time (s): 0.7433
# [7] Improvement: 385.55819685371534	Time (s): 0.712
# [8] Improvement: 425.37387342666625	Time (s): 0.7418
# [9] Improvement: 317.75743300015165	Time (s): 0.7321
# [10] Improvement: 165.38103265802783	Time (s): 0.7638
# [11] Improvement: 78.4646969800815	Time (s): 0.6985
# [12] Improvement: 43.3658667983691	Time (s): 0.7168
# Total Training Improvement: 2168.601823224075
# Total Training Time (s): 9.6346
# Vertical log prob = -124107.5609
# Use vertical split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_4_num_states_7_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_4_num_states_7_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_4_num_states_7_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_4_num_states_7_num_merging_0/test.csv
# **************************************************
# Current split     = 5.
# Current # states  = 7.
# Current # merging = 0.
# Current # splits  = 4.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: V00 <- T00 <- S01.
# Try temperal split.
# [1] Improvement: 19.911046159046236	Time (s): 0.7889
# Total Training Improvement: 19.911046159046236
# Total Training Time (s): 1.5642
# Temperal log prob = -124087.5940
# Try vertical split.
# [1] Improvement: 146.76400883343013	Time (s): 0.7852
# [2] Improvement: 23.652420785452705	Time (s): 0.7815
# [3] Improvement: 20.049123595439596	Time (s): 0.7752
# [4] Improvement: 18.894486201606924	Time (s): 0.7691
# Total Training Improvement: 209.36003941592935
# Total Training Time (s): 3.8444
# Vertical log prob = -124039.0844
# Use vertical split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_5_num_states_8_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_5_num_states_8_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_5_num_states_8_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_5_num_states_8_num_merging_0/test.csv
# **************************************************
# Current split     = 6.
# Current # states  = 8.
# Current # merging = 0.
# Current # splits  = 5.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: V01 <- V00 <- T00 <- S01.
# Try temperal split.
# [1] Improvement: 18.263186852593208	Time (s): 0.7635
# Total Training Improvement: 18.263186852593208
# Total Training Time (s): 1.6650
# Temperal log prob = -124020.8244
# Try vertical split.
# [1] Improvement: 41.51860554017185	Time (s): 1.184
# [2] Improvement: 19.850734963241848	Time (s): 1.356
# Total Training Improvement: 61.369340503413696
# Total Training Time (s): 3.3557
# Vertical log prob = -124011.8971
# Use vertical split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_6_num_states_9_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_6_num_states_9_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_6_num_states_9_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_6_num_states_9_num_merging_0/test.csv
# **************************************************
# Current split     = 7.
# Current # states  = 9.
# Current # merging = 0.
# Current # splits  = 6.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: V02 <- V01 <- V00 <- T00 <- S01.
# Try temperal split.
# [1] Improvement: 20.017177662724862	Time (s): 1.448
# [2] Improvement: 18.882156563311582	Time (s): 1.446
# Total Training Improvement: 38.899334226036444
# Total Training Time (s): 4.2960
# Temperal log prob = -123973.0554
# Try vertical split.
# [1] Improvement: 25.23248980921926	Time (s): 0.8344
# [2] Improvement: 18.582991538438364	Time (s): 0.874
# Total Training Improvement: 43.815481347657624
# Total Training Time (s): 2.8566
# Vertical log prob = -123978.2933
# Use temperal split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_7_num_states_10_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_7_num_states_10_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_7_num_states_10_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/craigslist/bert-base-uncased-craigslist-wwm/bert_mean_pooler_output/num_clusters_14/num_splits_7_num_states_10_num_merging_0/test.csv
