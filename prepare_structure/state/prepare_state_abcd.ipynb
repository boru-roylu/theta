# %%
import os
import sys
sys.path.append('../../src')

import copy
import collections
import datasets
import decouple
import json
import pandas as pd

import clustering
import clustering_utils
import utils

SCRATCH_DIR = decouple.config('SCRATCH_PARENT_DIR')
NFS_DIR = decouple.config('NFS_PARENT_DIR')

# %%
data_name = 'abcd'
num_clusters = 60
embedding_name = 'bert_mean_pooler_output'
cuda_device = 0
debug_mode = False
n_jobs = 8
overwrite = True

task_name = 'pretrain'
pos_type = 'absolute'

model_name = 'hibert'
data_config_path = f'../../config/data/{data_name}.yaml'

# %%
data_config = utils.read_yaml(data_config_path)

hmm_config_path = f'../../config/hmm/{data_name}.yaml' 
hmm_config = utils.read_yaml(hmm_config_path)

model_path = data_config['path']['dapt_model_path'].format(nfs_dir=NFS_DIR)
assert os.path.isdir(model_path), model_path

assignment_parent_dir = data_config['path']['assignment_dir'].format(nfs_dir=NFS_DIR)
assignment_dir = os.path.join(
    assignment_parent_dir, f'{embedding_name}/num_clusters_{num_clusters}')

state_assignment_parent_dir = \
    data_config['path']['state_assignment_dir'].format(nfs_dir=NFS_DIR)
os.makedirs(state_assignment_parent_dir, exist_ok=True)

print(f'{model_path = }')
print(f'{assignment_dir = }')
print(f'{state_assignment_parent_dir = }')

dataset_dir = data_config['path']['dataset_dir'].format(scratch_dir=SCRATCH_DIR)

local_ds_dir = utils.get_dataset_dir_map(
    task_name, dataset_dir, model_path, debug_mode)

raw_ds = datasets.DatasetDict.load_from_disk(local_ds_dir['raw_ds'])
ds = copy.deepcopy(raw_ds)
ds.set_format(type='torch', columns=['input_ids', 'attention_mask'])
# Out:
# model_path = '/gscratch/tial/roylu/projects/conversation_pretraining/pretrained_models/abcd/bert-base-uncased-abcd-wwm'
# assignment_dir = '/gscratch/tial/roylu/projects/conversation_pretraining/assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60'
# state_assignment_parent_dir = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm'

# %% [markdown]
# # Shows an example.

# %%
idx = 4
for turn in raw_ds['train']['dialogue'][idx]:
    utt = turn['turn']
    party = turn['party']
    print(f'{party:>10}: {utt}')
# Out:
#      agent: Hello, how can i help you
#   customer: Hello. I have a really cool party coming up. And I need some new clothes ASAP. I am thinking of ordering them to come by overnight shipping
#   customer: Do you know how much that costs?
#      agent: You want to know how much overnight shipping is, correct?
#   customer: yes
#   customer: like how much it costs
#   customer: I imagine that there is an extra fee
#   customer: i want these clothes quickly
#   customer: but I can't afford to pay too much
#      agent: The rate is for 39.99 for items 5 lbs or less. And 54.99 for items of 10 lbs or lesss and 69.99 for items over that.
#   customer: oh wow
#   customer: that's kind of expensive
#      agent: Yes it is expensive.
#   customer: okay, well that's good to know
#      agent: But they will come fast.
#      agent: Do you need anymore help?
#   customer: maybe I will just wear some old clothes to the party
#   customer: no, that's it
#      agent: Okay have a great day!
#   customer: i just needed to know about the shipping

# %%
split_to_cluster_seq_df = {}
split_to_centers = {}
for split in data_config['config']['splits']:
    assignment_path = os.path.join(assignment_dir, f'{split}.csv')
    center_path = os.path.join(assignment_dir, f'{split}_center.json')
    parties = [turn['party'] 
        for dialogue in raw_ds[split]['dialogue'] for turn in dialogue]
    df = pd.read_csv(assignment_path)
    df['party'] = parties
    cluster_seq_df = df.groupby('dialog_idx')['assignment'].apply(
        list).reset_index(name='cluster_sequence')
    cluster_seq_df['party_sequence'] = df.groupby('dialog_idx')['party'].apply(
        list)
    cluster_seq_df['turn_idx'] = df.groupby('dialog_idx')['turn_idx'].apply(
        list)

    split_to_cluster_seq_df[split] = cluster_seq_df

    with open(center_path, 'r') as f:
        split_to_centers[split] = json.load(f)

# %%
init_min_seq_len = hmm_config['init_min_seq_len']
topk_edges = hmm_config['topk_edges']
num_init_states = hmm_config['num_init_states']
max_iterations = hmm_config['max_iterations']
num_state_splits = hmm_config['num_state_splits']
topk_clusters = 3
topk_utterances_per_cluster = 3
topk_utterances_per_cluster_in_state = 10
n_jobs = 8
index_to_party = {v: k for k, v in data_config['config']['party_to_index'].items()}
speaker1 = index_to_party[0]
speaker2 = index_to_party[1]

# %%
cluster_to_utterances = {}
for cluster, neighbors in split_to_centers['train'].items():
    cluster_to_utterances[cluster] = \
        [f"{n['party']}: {n['turn']}" 
         for n in neighbors][:topk_utterances_per_cluster]

# %%
train_sequences = split_to_cluster_seq_df['train']['cluster_sequence'].tolist()
dev_sequences = split_to_cluster_seq_df['dev']['cluster_sequence'].tolist()
cluster_vocab = list(set(sum(train_sequences+dev_sequences, [])))

# Make sure if we don't have any missing clusters for a party.
if len(cluster_vocab) != num_clusters * 2:
    cluster_vocab = list(range(num_clusters * 2))

# %% [markdown]
# # Trains HMM and apply state-splitting algorithm to build topologies.

# %%
# Initializes 3-state left-to-right topology.
hmm = clustering.DiscreteSequenceClustering(
    init_min_seq_len,
    cluster_vocab,
    num_init_states=num_init_states,
    topk_edges=topk_edges)

hmm.build(train_sequences)

curr_split = 0
state_assignment_dir = os.path.join(
    state_assignment_parent_dir, 
    f'{embedding_name}/num_clusters_{num_clusters}/'
    f'num_splits_{hmm.num_splits}_num_states_{hmm.num_states}_num_merging_{hmm.num_merging}')
utils.maybe_makedirs(state_assignment_dir, overwrite)

print(f'Total # splits = {num_state_splits}')
num_states_to_model = {}
for curr_split in range(1, num_state_splits+1):

    print('*'*50)
    print(f'Current split     = {curr_split}.')
    print(f'Current # states  = {hmm.num_states}.')
    print(f'Current # merging = {hmm.num_merging}.')
    print(f'Current # splits  = {hmm.num_splits}.')
    print('*'*50)

    print('='*50)
    print(f'Start splitting.')
    print('='*50)
    hmm.split_and_train(train_sequences, train_sequences, max_iterations, n_jobs)

    state_assignment_parent_dir, 
    state_assignment_dir = os.path.join(
        state_assignment_parent_dir, 
        f'{embedding_name}/num_clusters_{num_clusters}/'
        f'num_splits_{hmm.num_splits}_num_states_{hmm.num_states}_num_merging_{hmm.num_merging}')
    utils.maybe_makedirs(state_assignment_dir, overwrite)
    checkpoint_path = os.path.join(state_assignment_dir, f'hmm.joblib')

    hmm.save_model(checkpoint_path)
    num_states_to_model[hmm.num_states] = copy.deepcopy(hmm)
    print(f'Save hmm to {checkpoint_path = }')
    print('\n\n')

    title = state_assignment_dir

    # Plots figure and predicts state sequneces.
    hmm = clustering.ClusteringBase.from_pretrained(checkpoint_path)
    g = clustering.plot_hmm(hmm, topk_clusters, cluster_to_utterances, title=state_assignment_dir)
    image_path = os.path.join(state_assignment_dir, 'hmm')
    g.render(image_path, format='pdf')

    split_to_state_df = {}
    for split, seq_df in split_to_cluster_seq_df.items():
        sequences = seq_df['cluster_sequence'].tolist()
        seq_df['state_sequence'] = list(map(hmm.predict, sequences))
        df = seq_df[['dialog_idx', 'turn_idx', 'state_sequence']].explode(
            ['turn_idx', 'state_sequence']).reset_index(drop=True)
        df.rename(columns={'state_sequence': 'assignment'}, inplace=True)
        split_to_state_df[split] = df
        path = os.path.join(state_assignment_dir, f'{split}.csv')
        df.to_csv(path, index=False)
        print(f'Saves state assignment to {path}')
        
    clustering_utils.find_state_centers(
        data_config['config']['splits'],
        raw_ds,
        assignment_dir,
        state_assignment_dir,
        split_to_state_df,
        split_to_centers,
        topk_clusters_in_state=3)
# Out:
# Total # splits = 9
# **************************************************
# Current split     = 1.
# Current # states  = 3.
# Current # merging = 0.
# Current # splits  = 0.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: S01.
# Try temperal split.
# [1] Improvement: 40919.20967077336	Time (s): 1.265
# [2] Improvement: 12959.408138327068	Time (s): 1.269
# [3] Improvement: 6036.0521729043685	Time (s): 1.264
# [4] Improvement: 1584.6872912468389	Time (s): 1.245
# [5] Improvement: 614.3913434912683	Time (s): 1.265
# [6] Improvement: 305.9044016979169	Time (s): 1.271
# [7] Improvement: 171.94833191903308	Time (s): 1.244
# [8] Improvement: 111.07097586267628	Time (s): 1.228
# [9] Improvement: 79.78825143235736	Time (s): 1.4
# [10] Improvement: 61.23927674093284	Time (s): 1.425
# [11] Improvement: 49.26496608497109	Time (s): 1.433
# [12] Improvement: 41.69319577026181	Time (s): 1.401
# Total Training Improvement: 62934.65801625105
# Total Training Time (s): 16.9519
# Temperal log prob = -533395.3262
# Try vertical split.
# [1] Improvement: 41403.6653120477	Time (s): 1.256
# [2] Improvement: 6914.954843080486	Time (s): 1.255
# [3] Improvement: 5184.122198365396	Time (s): 1.259
# [4] Improvement: 3252.6710901260376	Time (s): 1.255
# [5] Improvement: 1540.822196799796	Time (s): 1.251
# [6] Improvement: 698.8094749802258	Time (s): 1.246
# [7] Improvement: 387.34744653024245	Time (s): 1.234
# [8] Improvement: 246.04064329655375	Time (s): 1.245
# [9] Improvement: 166.36141884082463	Time (s): 1.245
# [10] Improvement: 111.30725804180838	Time (s): 1.246
# [11] Improvement: 71.5892041666666	Time (s): 1.259
# [12] Improvement: 44.41631046112161	Time (s): 1.25
# Total Training Improvement: 60022.10739673686
# Total Training Time (s): 16.0369
# Vertical log prob = -543009.0713
# Use temperal split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_1_num_states_4_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_1_num_states_4_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_1_num_states_4_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_1_num_states_4_num_merging_0/test.csv
# **************************************************
# Current split     = 2.
# Current # states  = 4.
# Current # merging = 0.
# Current # splits  = 1.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: T00 <- S01.
# Try temperal split.
# [1] Improvement: 48.1417738457676	Time (s): 1.398
# [2] Improvement: 82.98454399744514	Time (s): 1.415
# [3] Improvement: 131.68304229865316	Time (s): 1.421
# [4] Improvement: 254.91347432450857	Time (s): 1.392
# [5] Improvement: 683.3399379750481	Time (s): 1.398
# [6] Improvement: 2247.1333294332726	Time (s): 1.419
# [7] Improvement: 3045.803554192884	Time (s): 1.386
# [8] Improvement: 1151.9346835515462	Time (s): 1.404
# [9] Improvement: 279.4342463189969	Time (s): 1.381
# [10] Improvement: 140.37844121654052	Time (s): 1.396
# [11] Improvement: 99.32043941132724	Time (s): 1.382
# [12] Improvement: 71.78544827969745	Time (s): 1.552
# Total Training Improvement: 8236.852914845687
# Total Training Time (s): 18.3499
# Temperal log prob = -525112.2963
# Try vertical split.
# [1] Improvement: 6238.037222251296	Time (s): 1.574
# [2] Improvement: 3649.729215419735	Time (s): 1.402
# [3] Improvement: 536.5920135781635	Time (s): 1.383
# [4] Improvement: 160.4502419747878	Time (s): 1.388
# [5] Improvement: 119.12248191901017	Time (s): 1.382
# [6] Improvement: 116.4642498936737	Time (s): 1.545
# [7] Improvement: 105.17979465448298	Time (s): 1.573
# [8] Improvement: 78.27581590425689	Time (s): 1.552
# [9] Improvement: 48.57538147747982	Time (s): 1.466
# [10] Improvement: 27.765106158913113	Time (s): 1.414
# [11] Improvement: 16.40981848631054	Time (s): 1.381
# Total Training Improvement: 11096.60134171811
# Total Training Time (s): 17.6120
# Vertical log prob = -524637.8413
# Use vertical split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_2_num_states_5_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_2_num_states_5_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_2_num_states_5_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_2_num_states_5_num_merging_0/test.csv
# **************************************************
# Current split     = 3.
# Current # states  = 5.
# Current # merging = 0.
# Current # splits  = 2.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: T00 <- S01.
# Try temperal split.
# [1] Improvement: 24.16912946035154	Time (s): 1.624
# [2] Improvement: 39.01969109312631	Time (s): 1.653
# [3] Improvement: 43.33563726628199	Time (s): 1.745
# [4] Improvement: 172.5726244172547	Time (s): 1.753
# [5] Improvement: 730.4690245232196	Time (s): 1.748
# [6] Improvement: 982.0019154340262	Time (s): 1.743
# [7] Improvement: 1002.2807193706976	Time (s): 1.755
# [8] Improvement: 1221.0095807870384	Time (s): 1.753
# [9] Improvement: 1221.457644566719	Time (s): 1.761
# [10] Improvement: 706.7464506641845	Time (s): 1.754
# [11] Improvement: 250.20265710604144	Time (s): 1.765
# [12] Improvement: 182.23424849432195	Time (s): 1.742
# Total Training Improvement: 6575.499323183263
# Total Training Time (s): 22.3254
# Temperal log prob = -517875.0179
# Try vertical split.
# [1] Improvement: 3078.6098956027417	Time (s): 1.767
# [2] Improvement: 977.8176457326044	Time (s): 1.779
# [3] Improvement: 577.8929376667948	Time (s): 1.824
# [4] Improvement: 339.69004922831664	Time (s): 1.791
# [5] Improvement: 349.12029671960045	Time (s): 1.864
# [6] Improvement: 370.7521310040029	Time (s): 1.766
# [7] Improvement: 284.1035419225809	Time (s): 1.759
# [8] Improvement: 180.28473059635144	Time (s): 1.757
# [9] Improvement: 109.07587217196124	Time (s): 1.765
# [10] Improvement: 69.04945576179307	Time (s): 1.752
# [11] Improvement: 48.72435022657737	Time (s): 1.765
# [12] Improvement: 38.556998377956916	Time (s): 1.779
# Total Training Improvement: 6423.677905011282
# Total Training Time (s): 23.0877
# Vertical log prob = -520474.8903
# Use temperal split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_3_num_states_6_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_3_num_states_6_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_3_num_states_6_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_3_num_states_6_num_merging_0/test.csv
# **************************************************
# Current split     = 4.
# Current # states  = 6.
# Current # merging = 0.
# Current # splits  = 3.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: T01 <- T00 <- S01.
# Try temperal split.
# [1] Improvement: 234.2708966063219	Time (s): 1.919
# [2] Improvement: 316.27389385778224	Time (s): 1.904
# [3] Improvement: 410.31852146814344	Time (s): 1.899
# [4] Improvement: 465.54163257876644	Time (s): 1.835
# [5] Improvement: 428.8353344387142	Time (s): 1.766
# [6] Improvement: 348.75772751978366	Time (s): 1.947
# [7] Improvement: 286.3516575389658	Time (s): 1.916
# [8] Improvement: 253.85639959113905	Time (s): 1.94
# [9] Improvement: 239.07037359592505	Time (s): 1.933
# [10] Improvement: 230.4027082415996	Time (s): 1.895
# [11] Improvement: 224.30453452043002	Time (s): 1.92
# [12] Improvement: 219.65094390395097	Time (s): 1.907
# Total Training Improvement: 3657.6346238615224
# Total Training Time (s): 24.7072
# Temperal log prob = -514005.8753
# Try vertical split.
# [1] Improvement: 3565.3729694586364	Time (s): 1.876
# [2] Improvement: 1315.931961215625	Time (s): 1.912
# [3] Improvement: 859.2287333382992	Time (s): 1.922
# [4] Improvement: 605.3001605783938	Time (s): 1.924
# [5] Improvement: 530.0808062225115	Time (s): 1.909
# [6] Improvement: 497.7656036799308	Time (s): 1.912
# [7] Improvement: 462.7481394119677	Time (s): 1.941
# [8] Improvement: 439.271967669134	Time (s): 1.943
# [9] Improvement: 441.19549897057004	Time (s): 1.917
# [10] Improvement: 460.82869382796343	Time (s): 1.905
# [11] Improvement: 474.7068713114131	Time (s): 1.935
# [12] Improvement: 453.5539850516943	Time (s): 1.916
# Total Training Improvement: 10105.98539073614
# Total Training Time (s): 24.6347
# Vertical log prob = -509537.3039
# Use vertical split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_4_num_states_7_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_4_num_states_7_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_4_num_states_7_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_4_num_states_7_num_merging_0/test.csv
# **************************************************
# Current split     = 5.
# Current # states  = 7.
# Current # merging = 0.
# Current # splits  = 4.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: T00 <- S01.
# Try temperal split.
# [1] Improvement: 337.5773647018359	Time (s): 2.066
# [2] Improvement: 298.0545487233903	Time (s): 2.071
# [3] Improvement: 272.21732791530667	Time (s): 2.063
# [4] Improvement: 268.2151750549674	Time (s): 2.058
# [5] Improvement: 303.2041068460676	Time (s): 2.061
# [6] Improvement: 377.61401978798676	Time (s): 2.074
# [7] Improvement: 498.60996784985764	Time (s): 2.051
# [8] Improvement: 561.4519482009928	Time (s): 2.064
# [9] Improvement: 494.301644029445	Time (s): 2.082
# [10] Improvement: 373.77610608551186	Time (s): 2.08
# [11] Improvement: 300.4391712566139	Time (s): 2.082
# [12] Improvement: 267.44443639408564	Time (s): 2.083
# Total Training Improvement: 4352.9058168460615
# Total Training Time (s): 26.8840
# Temperal log prob = -504934.3538
# Try vertical split.
# [1] Improvement: 2268.898041600012	Time (s): 2.089
# [2] Improvement: 1756.3168079528841	Time (s): 2.09
# [3] Improvement: 1374.0818873239914	Time (s): 2.124
# [4] Improvement: 964.0198209289229	Time (s): 2.123
# [5] Improvement: 783.2593422659556	Time (s): 2.103
# [6] Improvement: 476.2036244091578	Time (s): 2.145
# [7] Improvement: 242.2851305064396	Time (s): 2.12
# [8] Improvement: 151.5836522296886	Time (s): 1.95
# [9] Improvement: 108.24436516925925	Time (s): 2.043
# [10] Improvement: 79.37557145574829	Time (s): 2.044
# [11] Improvement: 59.41577306599356	Time (s): 2.141
# [12] Improvement: 45.58944243926089	Time (s): 2.13
# Total Training Improvement: 8309.273459347314
# Total Training Time (s): 27.1613
# Vertical log prob = -502457.5639
# Use vertical split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_5_num_states_8_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_5_num_states_8_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_5_num_states_8_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_5_num_states_8_num_merging_0/test.csv
# **************************************************
# Current split     = 6.
# Current # states  = 8.
# Current # merging = 0.
# Current # splits  = 5.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: T00 <- S01.
# Try temperal split.
# [1] Improvement: 34.72651018790202	Time (s): 2.224
# [2] Improvement: 54.98117842769716	Time (s): 2.225
# [3] Improvement: 40.463950532022864	Time (s): 2.241
# [4] Improvement: 33.83548540394986	Time (s): 2.239
# [5] Improvement: 32.83934594702441	Time (s): 2.154
# [6] Improvement: 30.668199379346333	Time (s): 2.239
# [7] Improvement: 26.465802126389463	Time (s): 2.234
# [8] Improvement: 23.89951809810009	Time (s): 2.254
# [9] Improvement: 23.770305177080445	Time (s): 2.236
# [10] Improvement: 30.291119433066342	Time (s): 2.253
# [11] Improvement: 39.2724036462605	Time (s): 2.258
# [12] Improvement: 64.23194665822666	Time (s): 2.241
# Total Training Improvement: 435.44576501706615
# Total Training Time (s): 29.0176
# Temperal log prob = -501913.1387
# Try vertical split.
# [1] Improvement: 2032.2206991411513	Time (s): 2.233
# [2] Improvement: 500.610116232594	Time (s): 2.269
# [3] Improvement: 169.04167627333663	Time (s): 2.256
# [4] Improvement: 69.46696556475945	Time (s): 2.265
# [5] Improvement: 46.19700239773374	Time (s): 2.254
# [6] Improvement: 38.07613076426787	Time (s): 2.279
# [7] Improvement: 34.37657829548698	Time (s): 2.223
# [8] Improvement: 33.58153383556055	Time (s): 2.261
# [9] Improvement: 36.42728658323176	Time (s): 2.231
# [10] Improvement: 43.57070088956971	Time (s): 2.231
# [11] Improvement: 55.05765972996596	Time (s): 2.234
# [12] Improvement: 68.75017047609435	Time (s): 2.247
# Total Training Improvement: 3127.3765201837523
# Total Training Time (s): 29.2151
# Vertical log prob = -500712.7627
# Use vertical split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_6_num_states_9_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_6_num_states_9_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_6_num_states_9_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_6_num_states_9_num_merging_0/test.csv
# **************************************************
# Current split     = 7.
# Current # states  = 9.
# Current # merging = 0.
# Current # splits  = 6.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: T00 <- S01.
# Try temperal split.
# [1] Improvement: 83.3259700985509	Time (s): 2.34
# [2] Improvement: 105.66341369156726	Time (s): 2.364
# [3] Improvement: 75.72525123792002	Time (s): 2.357
# [4] Improvement: 54.76137633860344	Time (s): 2.357
# [5] Improvement: 42.401885515486356	Time (s): 2.369
# [6] Improvement: 35.9285995248938	Time (s): 2.358
# [7] Improvement: 33.13392753753578	Time (s): 2.353
# [8] Improvement: 29.23286051233299	Time (s): 2.348
# [9] Improvement: 24.31644330767449	Time (s): 2.341
# [10] Improvement: 19.852388603554573	Time (s): 2.367
# Total Training Improvement: 504.3421163681196
# Total Training Time (s): 25.8954
# Temperal log prob = -500213.0353
# Try vertical split.
# [1] Improvement: 1703.1807032655342	Time (s): 2.333
# [2] Improvement: 555.2237089782138	Time (s): 2.353
# [3] Improvement: 236.9322211931576	Time (s): 2.35
# [4] Improvement: 78.53739753749687	Time (s): 2.349
# [5] Improvement: 28.95473759289598	Time (s): 2.346
# [6] Improvement: 14.177014929591678	Time (s): 2.352
# Total Training Improvement: 2617.00578349689
# Total Training Time (s): 16.4201
# Vertical log prob = -499402.5319
# Use vertical split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_7_num_states_10_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_7_num_states_10_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_7_num_states_10_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_7_num_states_10_num_merging_0/test.csv
# **************************************************
# Current split     = 8.
# Current # states  = 10.
# Current # merging = 0.
# Current # splits  = 7.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: V04 <- T00 <- S01.
# Try temperal split.
# [1] Improvement: 5.572930926864501	Time (s): 2.513
# Total Training Improvement: 5.572930926864501
# Total Training Time (s): 4.9458
# Temperal log prob = -499397.9133
# Try vertical split.
# [1] Improvement: 296.26631366746733	Time (s): 2.493
# [2] Improvement: 28.94828894379316	Time (s): 2.518
# [3] Improvement: 22.538355094846338	Time (s): 2.521
# [4] Improvement: 30.201076734170783	Time (s): 2.506
# [5] Improvement: 45.111509598616976	Time (s): 2.5
# [6] Improvement: 31.755556874966715	Time (s): 2.504
# [7] Improvement: 17.03468040021835	Time (s): 2.521
# Total Training Improvement: 471.85578131407965
# Total Training Time (s): 20.0636
# Vertical log prob = -499286.5156
# Use vertical split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_8_num_states_11_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_8_num_states_11_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_8_num_states_11_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_8_num_states_11_num_merging_0/test.csv
# **************************************************
# Current split     = 9.
# Current # states  = 11.
# Current # merging = 0.
# Current # splits  = 8.
# **************************************************
# ==================================================
# Start splitting.
# ==================================================
# The state with max entropy is: V05 <- V04 <- T00 <- S01.
# Try temperal split.
# [1] Improvement: -4.069773719005752	Time (s): 2.662
# Total Training Improvement: -4.069773719005752
# Total Training Time (s): 5.2438
# Temperal log prob = -499296.2856
# Try vertical split.
# [1] Improvement: 20.426254516351037	Time (s): 2.636
# [2] Improvement: 11.99263338703895	Time (s): 2.657
# Total Training Improvement: 32.41888790338999
# Total Training Time (s): 7.9235
# Vertical log prob = -499276.0316
# Use vertical split.
# Save hmm to checkpoint_path = '/gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_9_num_states_12_num_merging_0/hmm.joblib'
#
#
#
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_9_num_states_12_num_merging_0/train.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_9_num_states_12_num_merging_0/dev.csv
# Saves state assignment to /gscratch/tial/roylu/projects/conversation_pretraining/state_assignments/abcd/bert-base-uncased-abcd-wwm/bert_mean_pooler_output/num_clusters_60/num_splits_9_num_states_12_num_merging_0/test.csv
